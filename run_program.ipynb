# %%
# %time %run -i tissue_gene_expression_analysis.py
# Out:
# ...
# EXERCISE 34.5: TISSUE GENE EXPRESSION ANALYSIS
# ...
#
# 📊 Loading tissue_gene_expression dataset...
# ✓ Dataset loaded successfully
#   - Shape: (189, 500)
#   - Observations: 189
#   - Genes: 500
#   - Unique tissue types: 7
#   - Tissue types: ['cerebellum', 'colon', 'endometrium', 'hippocampus', 'kidney', 'liver', 'placenta']
#
# Tissue sample counts:
#   cerebellum: 38 samples
#   colon: 34 samples
#   endometrium: 15 samples
#   hippocampus: 31 samples
#   kidney: 39 samples
#   liver: 26 samples
#   placenta: 6 samples
#
# ...
# EXERCISE 1: Remove Row Means and Compute Distance Matrix
# ...
#
# ✓ Row means removed (data centered)
#   - Original mean per row: 7.4820
#   - Centered mean per row: 3.050728e-16
#
# ✓ Distance matrix computed
#   - Distance vector length: 17766
#   - Distance matrix shape: (189, 189)
#   - Mean distance: 20.9640
#   - Min distance: 0.0000
#   - Max distance: 34.4124
#
# ...
# EXERCISE 2: Hierarchical Clustering Dendrogram
# ...
#
# ...
